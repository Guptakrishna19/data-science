# %% [markdown]
# type error

# %%
age = "25"# user types 25
bonus = 5

result = age + bonus  
print(result);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 age = "25"# user types 25
#       2 bonus = 5
#       3
# ----> 4 result = age + bonus
#       5 print(result);
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 25# user types 25
bonus = 5

result = age + bonus  
print(result);
# Out:
# 30

# %%
# FIND AND FIX THE BUG
def calculate_area(length, width):
    return length * width

l = "5"    
w = "3"    

area = calculate_area(l, w)
print("Area:", area)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       4
#       5 l = "5"
#       6 w = "3"
#       7
# ----> 8 area = calculate_area(l, w)
#       9 print("Area:", area)
#
# Cell In[4], line 3, in calculate_area(length, width)
#       2 def calculate_area(length, width):
# ----> 3     return length * width
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
# FIND AND FIX THE BUG
def calculate_area(length, width):
    return length * width

l = 5    # came from form/input
w = 3   # came from form/input

area = calculate_area(l, w)
print("Area:", area)
# Out:
# Area: 15
