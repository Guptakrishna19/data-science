# %% [markdown]
# exercise by using breakpoint

# %%
nums = [10, 20, 30, 40, 50]

for i in range(len(nums) + 1):  # BUG!
    print(nums[i])
# Out:
# 10
# 20
# 30
# 40
# 50
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 nums = [10, 20, 30, 40, 50]
#       2
#       3 for i in range(len(nums) + 1):  # BUG!
# ----> 4     print(nums[i])  # 💥 IndexError at i=5
#       5
#       6
#       7
#
# IndexError: list index out of range

# %%
nums = [10, 20, 30]
total = 0
breakpoint()  # ← EXECUTION FREEZE HERE
for i in range(len(nums)):
    total += nums[i]
print (total )   # ← look here
# Out:
# 60
