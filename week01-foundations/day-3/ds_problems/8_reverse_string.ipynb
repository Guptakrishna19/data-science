# %%
def reverse_string(text):
    stack = list(text)
    reversed_text = ""
    while stack:
        reversed_text += stack.pop()
    return reversed_text
print(reverse_string("Hello, World!"))
# Out:
# !dlroW ,olleH

# %%
def reverse_string(text):

    stack = list(text)

    result = ""

    while stack:
        result += stack.pop()

    return result
print("nayan")
# Out:
# nayan

# %% [markdown]
# Complexity
# Time: O(n)
# Space: O(n)
