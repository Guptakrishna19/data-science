# %%
def frequency_count(nums):

    freq = {}

    for num in nums:
        freq[num] = freq.get(num, 0) + 1

    return freq


numbers = [1, 2, 2, 3, 3, 3]

print(frequency_count(numbers))
# Out:
# {1: 1, 2: 2, 3: 3}

# %%
def frequency_count(nums):

    freq = {}

    for num in nums:
        freq[num] = freq.get(num, 0) + 1

    return freq


numbers = [1, 2, 2, 3, 3, 3, 4, 5, 2, 3, 4, 8]

print(frequency_count(numbers))
# Out:
# {1: 1, 2: 3, 3: 4, 4: 2, 5: 1, 8: 1}

# %% [markdown]
# reapeated

# %%
def frequency_count(nums):

    freq = {}

    for num in nums:
        freq[num] = freq.get(num, 0) + 1

    return freq


numbers = [1, 1, 1, 1, 1]

print(frequency_count(numbers))
# Out:
# {1: 5}

# %% [markdown]
# Complexity
# Time - O(n)
# Space - O(n)
